# %%
# Importing Libraries
import numpy as np
import pandas as pd

# %% [markdown]
# # Spotify Music Project

# %% [markdown]
# ### Dataset cleaning and saving

# %%
# Reading all Music Genre Datasets
alt = pd.read_csv('alternative_music_data.csv') # Alternative-Rock Music Dataset
blues = pd.read_csv('blues_music_data.csv') # Blues Music Dataset
hhop = pd.read_csv('hiphop_music_data.csv') # Hip-Hop Music Dataset
indie = pd.read_csv('indie_alt_music_data.csv') # Indie-Rock Music Dataset
metal = pd.read_csv('metal_music_data.csv') # Metal Music Dataset
pop = pd.read_csv('pop_music_data.csv') # Pop Music Dataset
rock = pd.read_csv('rock_music_data.csv') # Rock Music Dataset

# %%
# Creating an initial reference point for shape and size of uncleaned dataset
alt.head(2)
# Out:
#   Artist Name       Track Name  Popularity  \
# 0       James             Laid          66
# 1    grandson  In Over My Head          60
#
#                                               Genres           Playlist  \
# 0  ['britpop', 'madchester', 'new wave', 'new wav...    Alternative 90s
# 1  ['modern alternative rock', 'modern rock', 'ro...  Alternative Beats
#
#    danceability  energy  key  loudness  mode  ...  instrumentalness  liveness  \
# 0         0.457   0.909    0    -9.451     1  ...          0.000276     0.135
# 1         0.582   0.817    0    -6.475     1  ...          0.015800     0.575
#
#    valence    tempo                      id  \
# 0    0.755  115.998  2CdS3DRqWR5LAhy4hM5X9W
# 1    0.622  155.124  3r0mb1tzAcCNoA8YRXuIhZ
#
#                                     uri  \
# 0  spotify:track:2CdS3DRqWR5LAhy4hM5X9W
# 1  spotify:track:3r0mb1tzAcCNoA8YRXuIhZ
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/2CdS3DRqWR5L...
# ...

# %%
blues.head(2)
# Out:
#       Artist Name                                         Track Name  \
# 0   T-Bone Walker  Call It Stormy Monday (But Tuesday Is Just As ...
# 1  Hayes McMullan                              Goin' Away Mama Blues
#
#    Popularity                                             Genres  \
# 0           4  ['blues', 'blues rock', 'chicago blues', 'elec...
# 1          23                                    ['delta blues']
#
#         Playlist  danceability  energy  key  loudness  mode  ...  \
# 0  Blues Origins         0.659   0.166    2   -14.523     0  ...
# 1    Delta Blues         0.701   0.205    3   -13.458     1  ...
#
#    instrumentalness  liveness  valence    tempo                      id  \
# 0           0.05020    0.1010    0.345   49.320  1hHzQMnAtUudMmN2YN9tyq
# 1           0.00359    0.0716    0.839  101.734  2uMARFwLTasuuQ6cEChVBn
#
#                                     uri  \
# 0  spotify:track:1hHzQMnAtUudMmN2YN9tyq
# 1  spotify:track:2uMARFwLTasuuQ6cEChVBn
#
# ...

# %%
hhop.head(2)
# Out:
#   Artist Name                                    Track Name  Popularity  \
# 0   21 Savage                                        Spiral          63
# 1   VIC MENSA  SHELTER ft Wyclef Jean, ft Chance The Rapper          55
#
#                                               Genres     Playlist  \
# 0                     ['atl hip hop', 'rap', 'trap']       No Cap
# 1  ['chicago rap', 'conscious hip hop', 'hip hop'...  Mellow Bars
#
#    danceability  energy  key  loudness  mode  ...  instrumentalness  liveness  \
# 0         0.814   0.659    2    -4.475     1  ...          0.025100     0.568
# 1         0.664   0.660    0    -5.284     1  ...          0.000002     0.190
#
#    valence   tempo                      id  \
# 0     0.13  88.506  5YaMZfnTGCk6Ze3AxEcoaY
# 1     0.47  90.106  2nKaHCeL3e5DNl3P7eZ5uo
#
#                                     uri  \
# 0  spotify:track:5YaMZfnTGCk6Ze3AxEcoaY
# 1  spotify:track:2nKaHCeL3e5DNl3P7eZ5uo
#
# ...

# %%
indie.head(2)
# Out:
#   Artist Name Track Name  Popularity  \
# 0       James       Laid          66
# 1  tøm hughes    obvious          30
#
#                                               Genres         Playlist  \
# 0  ['britpop', 'madchester', 'new wave', 'new wav...  Alternative 90s
# 1                                                 []      Lo-fi Indie
#
#    danceability  energy  key  loudness  mode  ...  instrumentalness  liveness  \
# 0         0.457   0.909    0    -9.451     1  ...          0.000276     0.135
# 1         0.626   0.287    5   -19.453     0  ...          0.000000     0.229
#
#    valence    tempo                      id  \
# 0    0.755  115.998  2CdS3DRqWR5LAhy4hM5X9W
# 1    0.268  107.815  4CsSN0KzU3bqhkrA7P3kIw
#
#                                     uri  \
# 0  spotify:track:2CdS3DRqWR5LAhy4hM5X9W
# 1  spotify:track:4CsSN0KzU3bqhkrA7P3kIw
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/2CdS3DRqWR5L...
# ...

# %%
metal.head(2)
# Out:
#   Artist Name Track Name  Popularity  \
# 0      Myrkur       Ella          42
# 1   Monuments   Deadnest          51
#
#                                               Genres          Playlist  \
# 0  ['autonomous black metal', 'avant-garde metal'...  Northern Spirits
# 1                                          ['djent']     Kickass Metal
#
#    danceability  energy  key  loudness  mode  ...  instrumentalness  liveness  \
# 0         0.240   0.313    5   -11.476     1  ...          0.000156     0.176
# 1         0.445   0.968    6    -2.563     1  ...          0.000010     0.338
#
#    valence    tempo                      id  \
# 0    0.131  101.673  6QXieDRlH4Ofjg864USffV
# 1    0.326  114.920  3IC74qNKqXdeydqyS1J5z5
#
#                                     uri  \
# 0  spotify:track:6QXieDRlH4Ofjg864USffV
# 1  spotify:track:3IC74qNKqXdeydqyS1J5z5
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/6QXieDRlH4Of...
# ...

# %%
pop.head(2)
# Out:
#   Artist Name                 Track Name  Popularity  \
# 0      Prides  A Wilder Heart - Acoustic          40
# 1   Sam Smith        Diamonds - Acoustic          59
#
#                                             Genres       Playlist  \
# 0                                               []  Acoustic Hits
# 1  ['dance pop', 'pop', 'post-teen pop', 'uk pop']  Hot Acoustics
#
#    danceability  energy  key  loudness  mode  ...  instrumentalness  liveness  \
# 0         0.440   0.339    0    -8.191     1  ...               0.0    0.0933
# 1         0.489   0.284   10    -8.699     0  ...               0.0    0.1370
#
#    valence    tempo                      id  \
# 0    0.353  110.063  4AF9tkZUxzpvTz8FfJ61ZS
# 1    0.335  186.337  4y8OZW2dyWRobsi2w0C64W
#
#                                     uri  \
# 0  spotify:track:4AF9tkZUxzpvTz8FfJ61ZS
# 1  spotify:track:4y8OZW2dyWRobsi2w0C64W
#
#                                           track_href  \
# ...

# %%
rock.head(2)
# Out:
#        Artist Name   Track Name  Popularity  \
# 0  God Street Wine  Nightingale           5
# 1      cleopatrick     hometown          63
#
#                                               Genres              Playlist  \
# 0                                       ['jam band']               The Lot
# 1  ['modern alternative rock', 'modern blues rock...  Ultimate Rock Gaming
#
#    danceability  energy  key  loudness  mode  ...  instrumentalness  liveness  \
# 0         0.732   0.710   10   -10.429     1  ...          0.005720    0.4570
# 1         0.315   0.826    7    -4.314     0  ...          0.000687    0.0703
#
#    valence    tempo                      id  \
# 0    0.825  123.098  6A9mRe1Eg6jUBaiLu1ppAJ
# 1    0.359  139.161  6p8DGrcAUBuLUgDIKcUn0P
#
#                                     uri  \
# 0  spotify:track:6A9mRe1Eg6jUBaiLu1ppAJ
# 1  spotify:track:6p8DGrcAUBuLUgDIKcUn0P
#
#                                           track_href  \
# ...

# %%
#lets see if there are any columns with missing values 
alt_columns=alt.columns[alt.isnull().any()]
alt[alt_columns].isnull().sum()
# Out:
# Series([], dtype: float64)

# %%
blues_columns=blues.columns[blues.isnull().any()]
blues[blues_columns].isnull().sum()
# Out:
# Series([], dtype: float64)

# %%
hhop_columns=hhop.columns[hhop.isnull().any()]
hhop[hhop_columns].isnull().sum()
# Out:
# Series([], dtype: float64)

# %%
indie_columns=indie.columns[indie.isnull().any()]
indie[indie_columns].isnull().sum()
# Out:
# Series([], dtype: float64)

# %%
metal_columns=metal.columns[metal.isnull().any()]
metal[metal_columns].isnull().sum()
# Out:
# Series([], dtype: float64)

# %%
pop_columns=pop.columns[pop.isnull().any()]
pop[pop_columns].isnull().sum()
# Out:
# Series([], dtype: float64)

# %%
rock_columns=rock.columns[rock.isnull().any()]
rock[rock_columns].isnull().sum()
# Out:
# Series([], dtype: float64)

# %%
# Dropping unnecessary columns
alt.drop(['track_href','uri', 'analysis_url'], axis=1, inplace=True)
blues.drop(['track_href','uri', 'analysis_url'], axis=1, inplace=True)
hhop.drop(['track_href','uri', 'analysis_url'], axis=1, inplace=True)
indie.drop(['track_href','uri', 'analysis_url'], axis=1, inplace=True)
metal.drop(['track_href','uri', 'analysis_url'], axis=1, inplace=True)
pop.drop(['track_href','uri', 'analysis_url'], axis=1, inplace=True)
rock.drop(['track_href','uri', 'analysis_url'], axis=1, inplace=True)

# %%
# Saving Cleaned Files for Exploratory Data Analysis (EDA)
alt.to_csv("altdata_cleansed.csv", encoding="utf-8")
blues.to_csv("bluesdata_cleansed.csv", encoding="utf-8")
hhop.to_csv("hhopdata_cleansed.csv", encoding="utf-8")
indie.to_csv("indiedata_cleansed.csv", encoding="utf-8")
metal.to_csv("metaldata_cleansed.csv", encoding="utf-8")
pop.to_csv("popdata_cleansed.csv", encoding="utf-8")
rock.to_csv("rockdata_cleansed.csv", encoding="utf-8")
